# %%
import numpy as np
import pandas as pd

# basic_data = pd.read_excel('../data/data_base.xlsx')
basic_data = pd.read_excel('../data/follow_up_data_base.xlsx')
first_row = basic_data.columns.tolist()
first_header = [x for x in first_row if 'Unnamed' not in x]


data_base_dict = {}
for header in first_header[::-1]:
    df_left = basic_data.iloc[:, basic_data.columns.get_loc(header):]
    basic_data = basic_data.iloc[:, :basic_data.columns.get_loc(header)]
    df_left.columns = df_left.iloc[0]
    df_left = df_left[1:]
    data_base_dict[header] = df_left
    print(df_left.head())

data_base_dict = dict(reversed(data_base_dict.items()))

print()
# Out:
# 0 Follow-up Time（xx weeks after surgery） ECOG PS  \
# 1                                    NaN     NaN
# 2                                    NaN     NaN
# 3                                    NaN     NaN
# 4                                    NaN     NaN
# 5                                    NaN     NaN
#
# 0 Appetite（1.Good 2.Fair 3.Poor） Weight（kg） Weight Changes After Surgery（kg）  \
# 1                            NaN        NaN                              NaN
# 2                            NaN        NaN                              NaN
# 3                            NaN        NaN                              NaN
# 4                            NaN        NaN                              NaN
# 5                            NaN        NaN                              NaN
#
# 0 BMI（1.Underweight 2.Normal 3.Overweight 4.Pre-obesity 5.Obesity）  \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
#
# 0 Mental State（1.Good 2.Fair 3.Poor） Sleep Quality（1.Good 2.Fair 3.Poor）  \
# 1                                NaN                                 NaN
# 2                                NaN                                 NaN
# 3                                NaN                                 NaN
# 4                                NaN                                 NaN
# 5                                NaN                                 NaN
#
# 0 Feces（1.Normal 2.Constipation 3.Diarrhoea 4.Others）  \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
#
# 0 小便（1.normal 2.oliguria 3.anuria 4.Frequent and Urgent Micturition 5.Dysuria 6.Hematuria）  \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
#
# 0  ... Conversion Therapy During Follow-up Interval（1.Yes;2.No）  \
# 1  ...                                                NaN
# 2  ...                                                NaN
# 3  ...                                                NaN
# 4  ...                                                NaN
# 5  ...                                                NaN
#
# 0 Therapy Method（1、TACE  2、HAIC  3、TACE+HAIC 4、Immunotherapy 5、Targeted Immunotherapy 6、TACE+Targeted Immunotherapy7、HAIC+Targeted Immunotherapy 8、TACE+HAIC+Targeted Immunotherapy  9、8+Radiotherapy 10、Others）  \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
#
# 0 Number of Local Treatment Cycles Number of Systemic Treatment Cycles  \
# 1                              NaN                                 NaN
# 2                              NaN                                 NaN
# 3                              NaN                                 NaN
# 4                              NaN                                 NaN
# 5                              NaN                                 NaN
#
# 0 systemic therapy drug 1 dose of systemic therapy drug 1  \
# 1                     NaN                             NaN
# 2                     NaN                             NaN
# 3                     NaN                             NaN
# 4                     NaN                             NaN
# 5                     NaN                             NaN
#
# 0 systemic therapy drug 2 dose of systemic therapy drug 2  \
# 1                     NaN                             NaN
# 2                     NaN                             NaN
# 3                     NaN                             NaN
# 4                     NaN                             NaN
# 5                     NaN                             NaN
#
# 0 systemic therapy drug 3 dose of systemic therapy drug 3
# 1                     NaN                             NaN
# 2                     NaN                             NaN
# 3                     NaN                             NaN
# 4                     NaN                             NaN
# 5                     NaN                             NaN
#
# [5 rows x 38 columns]
# 0 Follow-up Time（xx weeks after surgery） ECOG PS  \
# 1                                    NaN     NaN
# 2                                    NaN     NaN
# 3                                    NaN     NaN
# 4                                    NaN     NaN
# 5                                    NaN     NaN
#
# 0 Appetite（1.Good 2.Fair 3.Poor） Weight（kg） Weight Changes After Surgery（kg）  \
# 1                            NaN        NaN                              NaN
# 2                            NaN        NaN                              NaN
# 3                            NaN        NaN                              NaN
# 4                            NaN        NaN                              NaN
# 5                            NaN        NaN                              NaN
#
# 0 BMI（1.Underweight 2.Normal 3.Overweight 4.Pre-obesity 5.Obesity）  \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
#
# 0 Mental State（1.Good 2.Fair 3.Poor） Sleep Quality（1.Good 2.Fair 3.Poor）  \
# 1                                NaN                                 NaN
# 2                                NaN                                 NaN
# 3                                NaN                                 NaN
# 4                                NaN                                 NaN
# 5                                NaN                                 NaN
#
# 0 Feces（1.Normal 2.Constipation 3.Diarrhoea 4.Others）  \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
#
# 0 小便（1.normal 2.oliguria 3.anuria 4.Frequent and Urgent Micturition 5.Dysuria 6.Hematuria）  \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
#
# 0  ... Conversion Therapy During Follow-up Interval（1.Yes;2.No）  \
# 1  ...                                                NaN
# 2  ...                                                NaN
# 3  ...                                                NaN
# 4  ...                                                NaN
# 5  ...                                                NaN
#
# 0 Therapy Method（1、TACE  2、HAIC  3、TACE+HAIC 4、Immunotherapy 5、Targeted Immunotherapy 6、TACE+Targeted Immunotherapy7、HAIC+Targeted Immunotherapy 8、TACE+HAIC+Targeted Immunotherapy  9、8+Radiotherapy 10、Others）  \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
#
# 0 Number of Local Treatment Cycles Number of Systemic Treatment Cycles  \
# 1                              NaN                                 NaN
# 2                              NaN                                 NaN
# 3                              NaN                                 NaN
# 4                              NaN                                 NaN
# 5                              NaN                                 NaN
#
# 0 systemic therapy drug 1 dose of systemic therapy drug 1  \
# 1                     NaN                             NaN
# 2                     NaN                             NaN
# 3                     NaN                             NaN
# 4                     NaN                             NaN
# 5                     NaN                             NaN
#
# 0 systemic therapy drug 2 dose of systemic therapy drug 2  \
# 1                     NaN                             NaN
# 2                     NaN                             NaN
# 3                     NaN                             NaN
# 4                     NaN                             NaN
# 5                     NaN                             NaN
#
# 0 systemic therapy drug 3 dose of systemic therapy drug 3
# 1                     NaN                             NaN
# 2                     NaN                             NaN
# 3                     NaN                             NaN
# 4                     NaN                             NaN
# 5                     NaN                             NaN
#
# [5 rows x 38 columns]
# 0 Follow-up Time（xx weeks after surgery） ECOG PS  \
# 1                                    NaN     NaN
# 2                                    NaN     NaN
# 3                                    NaN     NaN
# 4                                    NaN     NaN
# 5                                    NaN     NaN
#
# 0 Appetite（1.Good 2.Fair 3.Poor） Weight（kg） Weight Changes After Surgery（kg）  \
# 1                            NaN        NaN                              NaN
# 2                            NaN        NaN                              NaN
# 3                            NaN        NaN                              NaN
# 4                            NaN        NaN                              NaN
# 5                            NaN        NaN                              NaN
#
# 0 BMI（1.Underweight 2.Normal 3.Overweight 4.Pre-obesity 5.Obesity）  \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
#
# 0 Mental State（1.Good 2.Fair 3.Poor） Sleep Quality（1.Good 2.Fair 3.Poor）  \
# 1                                NaN                                 NaN
# 2                                NaN                                 NaN
# 3                                NaN                                 NaN
# 4                                NaN                                 NaN
# 5                                NaN                                 NaN
#
# 0 Feces（1.Normal 2.Constipation 3.Diarrhoea 4.Others）  \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
#
# 0 小便（1.normal 2.oliguria 3.anuria 4.Frequent and Urgent Micturition 5.Dysuria 6.Hematuria）  \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
#
# 0  ... Conversion Therapy During Follow-up Interval（1.Yes;2.No）  \
# 1  ...                                                NaN
# 2  ...                                                NaN
# 3  ...                                                NaN
# 4  ...                                                NaN
# 5  ...                                                NaN
#
# 0 Therapy Method（1、TACE  2、HAIC  3、TACE+HAIC 4、Immunotherapy 5、Targeted Immunotherapy 6、TACE+Targeted Immunotherapy7、HAIC+Targeted Immunotherapy 8、TACE+HAIC+Targeted Immunotherapy  9、8+Radiotherapy 10、Others）  \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
#
# 0 Number of Local Treatment Cycles Number of Systemic Treatment Cycles  \
# 1                              NaN                                 NaN
# 2                              NaN                                 NaN
# 3                              NaN                                 NaN
# 4                              NaN                                 NaN
# 5                              NaN                                 NaN
#
# 0 systemic therapy drug 1 dose of systemic therapy drug 1  \
# 1                     NaN                             NaN
# 2                     NaN                             NaN
# 3                     NaN                             NaN
# 4                     NaN                             NaN
# 5                     NaN                             NaN
#
# 0 systemic therapy drug 2 dose of systemic therapy drug 2  \
# 1                     NaN                             NaN
# 2                     NaN                             NaN
# 3                     NaN                             NaN
# 4                     NaN                             NaN
# 5                     NaN                             NaN
#
# 0 systemic therapy drug 3 dose of systemic therapy drug 3
# 1                     NaN                             NaN
# 2                     NaN                             NaN
# 3                     NaN                             NaN
# 4                     NaN                             NaN
# 5                     NaN                             NaN
#
# [5 rows x 38 columns]
# 0 Follow-up Time（xx weeks after surgery） ECOG PS  \
# 1                                    NaN     NaN
# 2                                    NaN     NaN
# 3                                    NaN     NaN
# 4                                    NaN     NaN
# 5                                    NaN     NaN
#
# 0 Appetite（1.Good 2.Fair 3.Poor） Weight（kg） Weight Changes After Surgery（kg）  \
# 1                            NaN        NaN                              NaN
# 2                            NaN        NaN                              NaN
# 3                            NaN        NaN                              NaN
# 4                            NaN        NaN                              NaN
# 5                            NaN        NaN                              NaN
#
# 0 BMI（1.Underweight 2.Normal 3.Overweight 4.Pre-obesity 5.Obesity）  \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
#
# 0 Mental State（1.Good 2.Fair 3.Poor） Sleep Quality（1.Good 2.Fair 3.Poor）  \
# 1                                NaN                                 NaN
# 2                                NaN                                 NaN
# 3                                NaN                                 NaN
# 4                                NaN                                 NaN
# 5                                NaN                                 NaN
#
# 0 Feces（1.Normal 2.Constipation 3.Diarrhoea 4.Others）  \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
#
# 0 Urinate（1.normal 2.oliguria 3.anuria 4.Frequent and Urgent Micturition 5.Dysuria 6.Hematuria）  \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
#
# 0  ... Conversion Therapy During Follow-up Interval（1.Yes;2.No）  \
# 1  ...                                                NaN
# 2  ...                                                NaN
# 3  ...                                                NaN
# 4  ...                                                NaN
# 5  ...                                                NaN
#
# 0 Therapy Method（1、TACE  2、HAIC  3、TACE+HAIC 4、Immunotherapy 5、Targeted Immunotherapy 6、TACE+Targeted Immunotherapy7、HAIC+Targeted Immunotherapy 8、TACE+HAIC+Targeted Immunotherapy  9、8+Radiotherapy 10、Others）  \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
#
# 0 Number of Local Treatment Cycles Number of Systemic Treatment Cycles  \
# 1                              NaN                                 NaN
# 2                              NaN                                 NaN
# 3                              NaN                                 NaN
# 4                              NaN                                 NaN
# 5                              NaN                                 NaN
#
# 0 systemic therapy drug 1 dose of systemic therapy drug 1  \
# 1                     NaN                             NaN
# 2                     NaN                             NaN
# 3                     NaN                             NaN
# 4                     NaN                             NaN
# 5                     NaN                             NaN
#
# 0 systemic therapy drug 2 dose of systemic therapy drug 2  \
# 1                     NaN                             NaN
# 2                     NaN                             NaN
# 3                     NaN                             NaN
# 4                     NaN                             NaN
# 5                     NaN                             NaN
#
# 0 systemic therapy drug 3 dose of systemic therapy drug 3
# 1                     NaN                             NaN
# 2                     NaN                             NaN
# 3                     NaN                             NaN
# 4                     NaN                             NaN
# 5                     NaN                             NaN
#
# [5 rows x 38 columns]
# 0 Contact Information Date of Surgery(XX-XX-XX)
# 1              123456                       xxx
# 2              123456                       xxx
# 3              123456                       xxx
# 4              123456                       xxx
# 5              123456                       xxx

# %%
def split_data(basic_data):

   first_row = basic_data.columns.tolist()
   first_header = [x for x in first_row if 'Unnamed' not in x]

   data_base_dict = {}
   for header in first_header[::-1]:
      df_left = basic_data.iloc[:, basic_data.columns.get_loc(header):]
      basic_data = basic_data.iloc[:, :basic_data.columns.get_loc(header)]
      df_left.columns = df_left.iloc[0]
      df_left = df_left[1:]
      data_base_dict[header] = df_left

   data_base_dict = dict(reversed(data_base_dict.items()))

   return data_base_dict

# %%
data_base_path = '../data/data_base.xlsx'
basic_data = pd.read_excel(data_base_path)
data_base_dict = split_data(basic_data)
basic_info = data_base_dict['basic information about admission']
basic_info
# basic_info['typing'].value_counts()
male_stage = basic_info['gender (1.male;2.female)'].value_counts()

male_stage.index = ['male', 'female', ]
male_stage
# age_stage = basic_info['age（1.>=60 years old;2.40-59 years old;3.<40 years old）'].value_counts()
# age_stage.index = ['>=60 years', '40-59 years', '<40 years old']

# age_stage
# Out:
# male      30
# female    11
# Name: gender (1.male;2.female), dtype: int64

# %%
basic_data
# Out:
#   Unnamed: 0 入院基本信息   Unnamed: 2                   Unnamed: 3 Unnamed: 4  \
# 0         分型     姓名  性别（1.男；2.女）  年龄（1.>=60岁；2.40-59岁；3.<40岁）         ID
# 1        NaN      A            1                            1     123456
# 2        NaN      B            2                            2     123457
# 3        NaN      C            1                            3     123458
# 4        NaN      D            2                            1     123459
# 5        NaN      E            1                            2     123460
#
#      Unnamed: 5    Unnamed: 6 Unnamed: 7           术前治疗情况  \
# 0  首诊HCC CNLC分期  首诊HCC BCLC分期      首诊AFP  术前是否转化（1.是；2.否）
# 1           XXX           YYY        ZZZ              NaN
# 2           XXX           YYY        ZZZ              NaN
# 3           XXX           YYY        ZZZ              NaN
# 4           XXX           YYY        ZZZ              NaN
# 5           XXX           YYY        ZZZ              NaN
#
#                                           Unnamed: 9  ... Unnamed: 129  \
# 0  转化方案（1、TACE  2、HAIC  3、TACE+HAIC 4、免疫 5、靶免  6、...  ...   Hepatocyte
# 1                                                NaN  ...          NaN
# 2                                                NaN  ...          NaN
# 3                                                NaN  ...          NaN
# 4                                                NaN  ...          NaN
# 5                                                NaN  ...          NaN
#
#   Unnamed: 130 Unnamed: 131 Unnamed: 132 Unnamed: 133 Unnamed: 134  \
# 0         CD34          AFP        GPC-3          CK7        CDX-2
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN          NaN
# 5          NaN          NaN          NaN          NaN          NaN
#
#   Unnamed: 135 Unnamed: 136 Unnamed: 137 Unnamed: 138
# 0       HSP-70        Ki-67       网状纤维染色        PD-L1
# 1          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN
# 5          NaN          NaN          NaN          NaN
#
# [6 rows x 139 columns]
